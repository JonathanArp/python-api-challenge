# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress,pearsonr

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | may pen
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | leshukonskoye
# Processing Record 6 of Set 1 | valparaiso
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mitsamiouli
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | egvekinot
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | yumen
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | marsassoum
# Processing Record 22 of Set 1 | bubaque
# Processing Record 23 of Set 1 | acurenam
# Processing Record 24 of Set 1 | shelburne
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 1 | solnechnyy
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | west wendover
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | mackay
# Processing Record 32 of Set 1 | dandong
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | katsuura
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | awjilah
# Processing Record 38 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 1 | kourou
# Processing Record 40 of Set 1 | adwa
# Processing Record 41 of Set 1 | sabang
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | sorong
# Processing Record 49 of Set 1 | chase
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 0 of Set 2 | kupang
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | tiruchchirappalli
# Processing Record 4 of Set 2 | mollendo
# Processing Record 5 of Set 2 | atbasar
# Processing Record 6 of Set 2 | krasnoselkup
# Processing Record 7 of Set 2 | ko samui
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | rocha
# Processing Record 10 of Set 2 | taoudenni
# Processing Record 11 of Set 2 | oshikango
# Processing Record 12 of Set 2 | santander jimenez
# Processing Record 13 of Set 2 | conceicao da barra
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | port augusta
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | verkhnetulomskiy
# Processing Record 18 of Set 2 | okhotsk
# Processing Record 19 of Set 2 | rio gallegos
# Processing Record 20 of Set 2 | utica
# Processing Record 21 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | vanavara
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | aleksandrovskiy zavod
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | chikoy
# City not found. Skipping...
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | makakilo city
# Processing Record 32 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 2 | montepuez
# Processing Record 34 of Set 2 | banda aceh
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | morant bay
# Processing Record 37 of Set 2 | maniitsoq
# Processing Record 38 of Set 2 | avera
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | usinsk
# Processing Record 44 of Set 2 | svetlaya
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | mackenzie
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 0 of Set 3 | victoria
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | kahului
# Processing Record 3 of Set 3 | le locle
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | lazaro cardenas
# Processing Record 6 of Set 3 | santa cruz
# Processing Record 7 of Set 3 | santa maria
# Processing Record 8 of Set 3 | bataipora
# Processing Record 9 of Set 3 | casino
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | sao joao do piaui
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | weihe
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | komatipoort
# Processing Record 18 of Set 3 | ugoofaaru
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | marsabit
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | areia branca
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | muravlenko
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | sambava
# Processing Record 28 of Set 3 | praia
# Processing Record 29 of Set 3 | vestmannaeyjar
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | lluta
# Processing Record 32 of Set 3 | grand gaube
# Processing Record 33 of Set 3 | kurduvadi
# Processing Record 34 of Set 3 | pedernales
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | lensk
# Processing Record 37 of Set 3 | piedmont
# Processing Record 38 of Set 3 | ixtapa
# Processing Record 39 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 40 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 3 | vila velha
# Processing Record 42 of Set 3 | lata
# Processing Record 43 of Set 3 | belize
# Processing Record 44 of Set 3 | carbonear
# Processing Record 45 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 3 | manica
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | srednekolymsk
# Processing Record 0 of Set 4 | cidreira
# Processing Record 1 of Set 4 | zhigansk
# Processing Record 2 of Set 4 | namibe
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | flinders
# Processing Record 7 of Set 4 | kautokeino
# Processing Record 8 of Set 4 | hofn
# Processing Record 9 of Set 4 | burnie
# Processing Record 10 of Set 4 | upata
# Processing Record 11 of Set 4 | hambantota
# Processing Record 12 of Set 4 | derzhavinsk
# Processing Record 13 of Set 4 | danville
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | ponta delgada
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | copiapo
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | ambovombe
# Processing Record 20 of Set 4 | havoysund
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | sioux lookout
# Processing Record 23 of Set 4 | dudinka
# Processing Record 24 of Set 4 | puerto ayora
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | saskylakh
# Processing Record 27 of Set 4 | clyde river
# Processing Record 28 of Set 4 | chumikan
# Processing Record 29 of Set 4 | laguna
# Processing Record 30 of Set 4 | muros
# Processing Record 31 of Set 4 | grindavik
# Processing Record 32 of Set 4 | minab
# Processing Record 33 of Set 4 | fort nelson
# Processing Record 34 of Set 4 | bom jesus
# Processing Record 35 of Set 4 | eureka
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | gazojak
# Processing Record 39 of Set 4 | moose factory
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | basco
# Processing Record 43 of Set 4 | arraial do cabo
# Processing Record 44 of Set 4 | lahij
# Processing Record 45 of Set 4 | zaysan
# Processing Record 46 of Set 4 | morondava
# Processing Record 47 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 4 | canberra
# Processing Record 49 of Set 4 | kysyl-syr
# Processing Record 0 of Set 5 | rawson
# Processing Record 1 of Set 5 | is
# City not found. Skipping...
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | mizdah
# Processing Record 4 of Set 5 | jamestown
# Processing Record 5 of Set 5 | babati
# Processing Record 6 of Set 5 | kikwit
# Processing Record 7 of Set 5 | saint-joseph
# Processing Record 8 of Set 5 | geraldton
# Processing Record 9 of Set 5 | bilma
# Processing Record 10 of Set 5 | sonda
# Processing Record 11 of Set 5 | aleksin
# Processing Record 12 of Set 5 | narsaq
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | caravelas
# Processing Record 15 of Set 5 | kazachinskoye
# Processing Record 16 of Set 5 | san patricio
# Processing Record 17 of Set 5 | peniche
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | pacific grove
# Processing Record 20 of Set 5 | college station
# Processing Record 21 of Set 5 | richards bay
# Processing Record 22 of Set 5 | ahipara
# Processing Record 23 of Set 5 | port pirie
# Processing Record 24 of Set 5 | nampula
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | lodja
# Processing Record 28 of Set 5 | tigil
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | burns lake
# Processing Record 31 of Set 5 | luderitz
# Processing Record 32 of Set 5 | biak
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 5 | kavieng
# Processing Record 36 of Set 5 | baykit
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | tual
# Processing Record 39 of Set 5 | tres arroyos
# Processing Record 40 of Set 5 | sombrerete
# Processing Record 41 of Set 5 | vizinga
# Processing Record 42 of Set 5 | yinchuan
# Processing Record 43 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | porto novo
# Processing Record 45 of Set 5 | kollam
# Processing Record 46 of Set 5 | charters towers
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | at-bashi
# Processing Record 0 of Set 6 | sukhobezvodnoye
# Processing Record 1 of Set 6 | adelaide
# Processing Record 2 of Set 6 | polur
# Processing Record 3 of Set 6 | dickinson
# Processing Record 4 of Set 6 | mar del plata
# Processing Record 5 of Set 6 | matara
# Processing Record 6 of Set 6 | kamaishi
# Processing Record 7 of Set 6 | shenjiamen
# Processing Record 8 of Set 6 | yura
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | tura
# Processing Record 11 of Set 6 | hami
# Processing Record 12 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 6 | bay roberts
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | saint-francois
# Processing Record 16 of Set 6 | linqu
# Processing Record 17 of Set 6 | zlocieniec
# Processing Record 18 of Set 6 | abidjan
# Processing Record 19 of Set 6 | elizabeth city
# Processing Record 20 of Set 6 | buala
# Processing Record 21 of Set 6 | mayahi
# Processing Record 22 of Set 6 | kodiak
# Processing Record 23 of Set 6 | barrow
# Processing Record 24 of Set 6 | kloulklubed
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | ulaangom
# Processing Record 27 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 6 | polis
# Processing Record 29 of Set 6 | dikson
# Processing Record 30 of Set 6 | haines junction
# Processing Record 31 of Set 6 | lovozero
# Processing Record 32 of Set 6 | brae
# Processing Record 33 of Set 6 | springfield
# Processing Record 34 of Set 6 | maloy
# Processing Record 35 of Set 6 | yar-sale
# Processing Record 36 of Set 6 | mora
# Processing Record 37 of Set 6 | azul
# Processing Record 38 of Set 6 | sinnamary
# Processing Record 39 of Set 6 | verkh-chebula
# Processing Record 40 of Set 6 | altay
# Processing Record 41 of Set 6 | kangaatsiaq
# Processing Record 42 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 6 | kiri buru
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | iquitos
# Processing Record 46 of Set 6 | hit
# Processing Record 47 of Set 6 | tumut
# Processing Record 48 of Set 6 | tocopilla
# Processing Record 49 of Set 6 | qandala
# Processing Record 0 of Set 7 | portland
# Processing Record 1 of Set 7 | itarema
# Processing Record 2 of Set 7 | pathein
# Processing Record 3 of Set 7 | minden
# Processing Record 4 of Set 7 | port-gentil
# Processing Record 5 of Set 7 | eslov
# Processing Record 6 of Set 7 | camacha
# Processing Record 7 of Set 7 | samarinda
# Processing Record 8 of Set 7 | manaure
# Processing Record 9 of Set 7 | medea
# Processing Record 10 of Set 7 | longyearbyen
# Processing Record 11 of Set 7 | boissevain
# Processing Record 12 of Set 7 | jalu
# Processing Record 13 of Set 7 | rubano
# Processing Record 14 of Set 7 | ayan
# Processing Record 15 of Set 7 | tessalit
# Processing Record 16 of Set 7 | leningradskiy
# Processing Record 17 of Set 7 | vanimo
# Processing Record 18 of Set 7 | sechura
# Processing Record 19 of Set 7 | bacolod
# Processing Record 20 of Set 7 | odienne
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | hirara
# Processing Record 23 of Set 7 | gouyave
# Processing Record 24 of Set 7 | jinchang
# Processing Record 25 of Set 7 | bedesa
# Processing Record 26 of Set 7 | delijan
# Processing Record 27 of Set 7 | batemans bay
# Processing Record 28 of Set 7 | seymchan
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | hamilton
# Processing Record 31 of Set 7 | gizo
# Processing Record 32 of Set 7 | sao filipe
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | chake chake
# Processing Record 35 of Set 7 | bonavista
# Processing Record 36 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 7 | novita
# Processing Record 38 of Set 7 | san luis
# Processing Record 39 of Set 7 | asmara
# Processing Record 40 of Set 7 | lethem
# Processing Record 41 of Set 7 | college
# Processing Record 42 of Set 7 | gazanjyk
# Processing Record 43 of Set 7 | henties bay
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | parabel
# Processing Record 46 of Set 7 | anadyr
# Processing Record 47 of Set 7 | kavaratti
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | beloha
# Processing Record 0 of Set 8 | marsa matruh
# Processing Record 1 of Set 8 | show low
# Processing Record 2 of Set 8 | jining
# Processing Record 3 of Set 8 | esperance
# Processing Record 4 of Set 8 | kjollefjord
# Processing Record 5 of Set 8 | north branch
# Processing Record 6 of Set 8 | sinjar
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | mnogovershinnyy
# Processing Record 9 of Set 8 | pavino
# Processing Record 10 of Set 8 | broome
# Processing Record 11 of Set 8 | iqaluit
# Processing Record 12 of Set 8 | conceicao do araguaia
# Processing Record 13 of Set 8 | newport
# Processing Record 14 of Set 8 | antofagasta
# Processing Record 15 of Set 8 | praya
# Processing Record 16 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 17 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 8 | sitka
# Processing Record 20 of Set 8 | mudgee
# Processing Record 21 of Set 8 | poum
# Processing Record 22 of Set 8 | manokwari
# Processing Record 23 of Set 8 | kameoka
# Processing Record 24 of Set 8 | shymkent
# Processing Record 25 of Set 8 | stekolnyy
# City not found. Skipping...
# Processing Record 26 of Set 8 | powell river
# Processing Record 27 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | kaitangata
# Processing Record 29 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 8 | klaksvik
# Processing Record 31 of Set 8 | torata
# Processing Record 32 of Set 8 | austin
# Processing Record 33 of Set 8 | mineiros
# Processing Record 34 of Set 8 | churapcha
# Processing Record 35 of Set 8 | molchanovo
# Processing Record 36 of Set 8 | santander
# Processing Record 37 of Set 8 | eregli
# Processing Record 38 of Set 8 | husavik
# Processing Record 39 of Set 8 | saint george
# Processing Record 40 of Set 8 | guasdualito
# Processing Record 41 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 42 of Set 8 | shimoda
# Processing Record 43 of Set 8 | walvis bay
# Processing Record 44 of Set 8 | andenes
# Processing Record 45 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 8 | taperoa
# Processing Record 47 of Set 8 | leeton
# Processing Record 48 of Set 8 | sibolga
# Processing Record 49 of Set 8 | whitehorse
# Processing Record 0 of Set 9 | hithadhoo
# Processing Record 1 of Set 9 | tatawin
# Processing Record 2 of Set 9 | imeni poliny osipenko
# Processing Record 3 of Set 9 | pangnirtung
# Processing Record 4 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 9 | sembakung
# Processing Record 6 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 9 | salalah
# Processing Record 8 of Set 9 | miloslavskoye
# Processing Record 9 of Set 9 | ginir
# Processing Record 10 of Set 9 | hauterive
# Processing Record 11 of Set 9 | ochamchira
# Processing Record 12 of Set 9 | baraboo
# Processing Record 13 of Set 9 | panguna
# Processing Record 14 of Set 9 | udachnyy
# Processing Record 15 of Set 9 | ballina
# Processing Record 16 of Set 9 | lavrentiya
# Processing Record 17 of Set 9 | nanakuli
# Processing Record 18 of Set 9 | bridlington
# Processing Record 19 of Set 9 | san cristobal
# Processing Record 20 of Set 9 | privokzalnyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | puerto escondido
# Processing Record 22 of Set 9 | micheweni
# Processing Record 23 of Set 9 | whyalla
# Processing Record 24 of Set 9 | edd
# Processing Record 25 of Set 9 | veraval
# Processing Record 26 of Set 9 | ishigaki
# Processing Record 27 of Set 9 | bardiyah
# Processing Record 28 of Set 9 | tiksi
# Processing Record 29 of Set 9 | norman wells
# Processing Record 30 of Set 9 | kardla
# Processing Record 31 of Set 9 | port lincoln
# Processing Record 32 of Set 9 | businga
# Processing Record 33 of Set 9 | grimshaw
# Processing Record 34 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 9 | pilar
# Processing Record 36 of Set 9 | kualakapuas
# Processing Record 37 of Set 9 | smithers
# Processing Record 38 of Set 9 | taltal
# Processing Record 39 of Set 9 | otradinskiy
# City not found. Skipping...
# Processing Record 40 of Set 9 | umkomaas
# Processing Record 41 of Set 9 | lapua
# Processing Record 42 of Set 9 | lorengau
# Processing Record 43 of Set 9 | doha
# Processing Record 44 of Set 9 | trelew
# Processing Record 45 of Set 9 | matias barbosa
# Processing Record 46 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 9 | quatre cocos
# Processing Record 48 of Set 9 | yanam
# Processing Record 49 of Set 9 | nhulunbuy
# Processing Record 0 of Set 10 | plainfield
# Processing Record 1 of Set 10 | yaan
# Processing Record 2 of Set 10 | kabompo
# Processing Record 3 of Set 10 | charlestown
# Processing Record 4 of Set 10 | pitimbu
# Processing Record 5 of Set 10 | coquimbo
# Processing Record 6 of Set 10 | palimbang
# Processing Record 7 of Set 10 | lagoa
# Processing Record 8 of Set 10 | olafsvik
# Processing Record 9 of Set 10 | fort-shevchenko
# Processing Record 10 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 11 of Set 10 | aranos
# Processing Record 12 of Set 10 | pilot butte
# Processing Record 13 of Set 10 | hobyo
# Processing Record 14 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 10 | north bend
# Processing Record 16 of Set 10 | qasigiannguit
# Processing Record 17 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 10 | yarada
# Processing Record 19 of Set 10 | zhangjiakou
# Processing Record 20 of Set 10 | progreso
# Processing Record 21 of Set 10 | naze
# Processing Record 22 of Set 10 | miles city
# Processing Record 23 of Set 10 | grand forks
# Processing Record 24 of Set 10 | zelenoborskiy
# Processing Record 25 of Set 10 | oslob
# Processing Record 26 of Set 10 | healesville
# Processing Record 27 of Set 10 | atasu
# Processing Record 28 of Set 10 | nemuro
# Processing Record 29 of Set 10 | rincon
# Processing Record 30 of Set 10 | skjervoy
# Processing Record 31 of Set 10 | turayf
# Processing Record 32 of Set 10 | prince rupert
# Processing Record 33 of Set 10 | abu kamal
# Processing Record 34 of Set 10 | inhambane
# Processing Record 35 of Set 10 | pervomayskoye
# Processing Record 36 of Set 10 | beringovskiy
# Processing Record 37 of Set 10 | belle glade
# Processing Record 38 of Set 10 | lasa
# Processing Record 39 of Set 10 | sol-iletsk
# Processing Record 40 of Set 10 | ustye
# Processing Record 41 of Set 10 | kholmogory
# Processing Record 42 of Set 10 | hede
# Processing Record 43 of Set 10 | kudahuvadhoo
# Processing Record 44 of Set 10 | araouane
# Processing Record 45 of Set 10 | port keats
# Processing Record 46 of Set 10 | ulladulla
# Processing Record 47 of Set 10 | santa fe
# Processing Record 48 of Set 10 | pimentel
# Processing Record 49 of Set 10 | tonneins
# Processing Record 0 of Set 11 | half moon bay
# Processing Record 1 of Set 11 | gushikawa
# Processing Record 2 of Set 11 | itaituba
# Processing Record 3 of Set 11 | beian
# Processing Record 4 of Set 11 | broken hill
# Processing Record 5 of Set 11 | port moresby
# Processing Record 6 of Set 11 | hervey bay
# Processing Record 7 of Set 11 | westport
# Processing Record 8 of Set 11 | dutlwe
# Processing Record 9 of Set 11 | catamarca
# Processing Record 10 of Set 11 | caninde
# Processing Record 11 of Set 11 | balkanabat
# Processing Record 12 of Set 11 | belaya
# Processing Record 13 of Set 11 | harper
# Processing Record 14 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 11 | manali
# Processing Record 16 of Set 11 | san cosme y damian
# Processing Record 17 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 11 | pochutla
# Processing Record 19 of Set 11 | ericeira
# Processing Record 20 of Set 11 | bull savanna
# Processing Record 21 of Set 11 | sungaipenuh
# Processing Record 22 of Set 11 | gayny
# Processing Record 23 of Set 11 | hovd
# Processing Record 24 of Set 11 | port blair
# Processing Record 25 of Set 11 | dwarka
# Processing Record 26 of Set 11 | nizwa
# Processing Record 27 of Set 11 | stromness
# Processing Record 28 of Set 11 | miri
# Processing Record 29 of Set 11 | gigmoto
# Processing Record 30 of Set 11 | sandwick
# Processing Record 31 of Set 11 | belyy yar
# Processing Record 32 of Set 11 | blackfalds
# Processing Record 33 of Set 11 | sattahip
# Processing Record 34 of Set 11 | mutis
# Processing Record 35 of Set 11 | qaqortoq
# Processing Record 36 of Set 11 | nchelenge
# Processing Record 37 of Set 11 | lebedyn
# Processing Record 38 of Set 11 | mama
# Processing Record 39 of Set 11 | yulara
# Processing Record 40 of Set 11 | cahors
# Processing Record 41 of Set 11 | comodoro rivadavia
# Processing Record 42 of Set 11 | dalbandin
# Processing Record 43 of Set 11 | san policarpo
# Processing Record 44 of Set 11 | popondetta
# Processing Record 45 of Set 11 | ravar
# Processing Record 46 of Set 11 | el dorado
# Processing Record 47 of Set 11 | kirakira
# Processing Record 48 of Set 11 | isla mujeres
# Processing Record 49 of Set 11 | pobe
# Processing Record 0 of Set 12 | hengshui
# Processing Record 1 of Set 12 | constantine
# Processing Record 2 of Set 12 | fethiye
# Processing Record 3 of Set 12 | aklavik
# Processing Record 4 of Set 12 | luanda
# Processing Record 5 of Set 12 | pitsunda
# Processing Record 6 of Set 12 | omboue
# Processing Record 7 of Set 12 | zhangye
# Processing Record 8 of Set 12 | brainerd
# Processing Record 9 of Set 12 | igrim
# Processing Record 10 of Set 12 | laurentides
# Processing Record 11 of Set 12 | plettenberg bay
# Processing Record 12 of Set 12 | paarl
# Processing Record 13 of Set 12 | menongue
# Processing Record 14 of Set 12 | moron
# Processing Record 15 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 16 of Set 12 | inyonga
# Processing Record 17 of Set 12 | garhi khairo
# Processing Record 18 of Set 12 | rodionovo-nesvetayskaya
# Processing Record 19 of Set 12 | faya
# Processing Record 20 of Set 12 | komsomolskiy
# Processing Record 21 of Set 12 | alvdal
# Processing Record 22 of Set 12 | dingle
# Processing Record 23 of Set 12 | asfi
# Processing Record 24 of Set 12 | rennes
# Processing Record 25 of Set 12 | alta floresta
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | port shepstone
# Processing Record 28 of Set 12 | codrington
# Processing Record 29 of Set 12 | sangar
# Processing Record 30 of Set 12 | korla
# Processing Record 31 of Set 12 | dubrovnik
# Processing Record 32 of Set 12 | yenagoa
# Processing Record 33 of Set 12 | jiaocheng
# Processing Record 34 of Set 12 | kathu
# Processing Record 35 of Set 12 | nizhnevartovsk
# Processing Record 36 of Set 12 | bathsheba
# Processing Record 37 of Set 12 | marienburg
# Processing Record 38 of Set 12 | sokolka
# Processing Record 39 of Set 12 | asau
# Processing Record 40 of Set 12 | munsingen
# Processing Record 41 of Set 12 | marovoay
# Processing Record 42 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 12 | aksarka
# Processing Record 44 of Set 12 | padang
# Processing Record 45 of Set 12 | meulaboh
# Processing Record 46 of Set 12 | dingli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          549
# Lat           549
# Lng           549
# Max Temp      549
# Humidity      549
# Cloudiness    549
# Wind Speed    549
# Country       549
# Date          549
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       hermanus -34.4187   19.2345     19.33        82           0
# 1        hualmay -11.0964  -77.6139     22.18        70          22
# 2        may pen  17.9645  -77.2451     30.56        48          35
# 3    yellowknife  62.4560 -114.3525    -17.71        78         100
# 4  leshukonskoye  64.8989   45.7622    -12.32        94         100
#
#    Wind Speed Country        Date
# 0        5.14      ZA  1670613556
# 1        4.53      PE  1670613556
# 2        2.61      JM  1670613557
# 3        3.60      CA  1670613557
# 4        3.84      RU  1670613558

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             hermanus -34.4187   19.2345     19.33        82           0
# 1              hualmay -11.0964  -77.6139     22.18        70          22
# 2              may pen  17.9645  -77.2451     30.56        48          35
# 3          yellowknife  62.4560 -114.3525    -17.71        78         100
# 4        leshukonskoye  64.8989   45.7622    -12.32        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      ZA  1670613556
# 1              4.53      PE  1670613556
# 2              2.61      JM  1670613557
# 3              3.60      CA  1670613557
# 4              3.84      RU  1670613558

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize= (6,5))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.grid()
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", facecolors="aqua", edgecolors="black")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize= (6,5))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.grid()
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", facecolors="aqua", edgecolors="black")


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize= (6,5))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.grid()
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", facecolors="aqua", edgecolors="black")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize= (6,5))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.grid()
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", facecolors="aqua", edgecolors="black")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2              may pen  17.9645  -77.2451     30.56        48          35
# 3          yellowknife  62.4560 -114.3525    -17.71        78         100
# 4        leshukonskoye  64.8989   45.7622    -12.32        94         100
# 9          provideniya  64.3833 -173.3000     -2.25        77          88
# 10          nikolskoye  59.7035   30.7861     -1.06        92          91
#
#          Wind Speed Country        Date
# City_ID
# 2              2.61      JM  1670613557
# 3              3.60      CA  1670613557
# 4              3.84      RU  1670613558
# 9             10.17      RU  1670613560
# 10             3.46      RU  1670613560

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           hermanus -34.4187  19.2345     19.33        82           0
# 1            hualmay -11.0964 -77.6139     22.18        70          22
# 5         valparaiso -33.0393 -71.6273     28.13        76           0
# 6            ushuaia -54.8000 -68.3000      9.81        62          40
# 7        mitsamiouli -11.3847  43.2844     27.20        71           9
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      ZA  1670613556
# 1              4.53      PE  1670613556
# 5              7.20      CL  1670613408
# 6              2.06      AR  1670613559
# 7              1.77      KM  1670613560

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
temp_northern_hemi = northern_hemi_df["Max Temp"]
lat_northern_hemi = northern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_northern_hemi, temp_northern_hemi)
temp_fit = temp_slope * lat_northern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_northern_hemi = pearsonr(lat_northern_hemi, temp_northern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(temp_line, (10, -40), fontsize = 12, color = "red")

plt.scatter(lat_northern_hemi, temp_northern_hemi)
plt.plot(lat_northern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.7433876875762551

# %%
## Linear regression on Southern Hemisphere
temp_southern_hemi = southern_hemi_df["Max Temp"]
lat_southern_hemi = southern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_southern_hemi, temp_southern_hemi)
temp_fit = temp_slope * lat_southern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_southern_hemi = pearsonr(lat_southern_hemi, temp_southern_hemi)

plt.figure(figsize= (4,3))
plt.ylim(5, 40)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(temp_line, (-50, 35), fontsize = 12, color = "red")

plt.scatter(lat_southern_hemi, temp_southern_hemi)
plt.plot(lat_southern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.15164268333982145

# %% [markdown]
# **Discussion about the linear relationship:** The northern hempishere shows a negative correlation between latitude and max temperature. The southern hemishphere shows a small positive correlation between latitude and max temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
humidity_northern_hemi = northern_hemi_df["Humidity"]
lat_northern_hemi = northern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_northern_hemi, humidity_northern_hemi)
temp_fit = temp_slope * lat_northern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_2_northern_hemi = pearsonr(lat_northern_hemi, humidity_northern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(temp_line, (40, 20), fontsize = 12, color = "red")

plt.scatter(lat_northern_hemi, humidity_northern_hemi)
plt.plot(lat_northern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.11627130738430096

# %%
# Southern Hemisphere
humidity_southern_hemi = southern_hemi_df["Humidity"]
lat_southern_hemi = southern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_southern_hemi, humidity_southern_hemi)
temp_fit = temp_slope * lat_southern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_2_southern_hemi = pearsonr(lat_southern_hemi, humidity_southern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(temp_line, (-50, 50), fontsize = 12, color = "red")

plt.scatter(lat_southern_hemi, humidity_southern_hemi)
plt.plot(lat_southern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.03867453718102262

# %% [markdown]
# **Discussion about the linear relationship:** The northern hemisphere shows a very slight positive correlation between latitiude and humidity. There is almost zero correlation between the two in the southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
cloudiness_northern_hemi = northern_hemi_df["Cloudiness"]
lat_northern_hemi = northern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_northern_hemi, cloudiness_northern_hemi)
temp_fit = temp_slope * lat_northern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_3_northern_hemi = pearsonr(lat_northern_hemi, cloudiness_northern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(temp_line, (40, 40), fontsize = 12, color = "red")

plt.scatter(lat_northern_hemi, cloudiness_northern_hemi)
plt.plot(lat_northern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.046425449207170955

# %%
# Southern Hemisphere
cloudiness_southern_hemi = southern_hemi_df["Cloudiness"]
lat_southern_hemi = southern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_southern_hemi, cloudiness_southern_hemi)
temp_fit = temp_slope * lat_southern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_3_southern_hemi = pearsonr(lat_southern_hemi, cloudiness_southern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(temp_line, (-50, 60), fontsize = 12, color = "red")

plt.scatter(lat_southern_hemi, cloudiness_southern_hemi)
plt.plot(lat_southern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.08437134540938744

# %% [markdown]
# **Discussion about the linear relationship:** There is a small positive correlation between latitiude and cloudiness in the northern and southern hemispheres.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
windspeed_northern_hemi = northern_hemi_df["Wind Speed"]
lat_northern_hemi = northern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_northern_hemi, windspeed_northern_hemi)
temp_fit = temp_slope * lat_northern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_4_northern_hemi = pearsonr(lat_northern_hemi, windspeed_northern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(temp_line, (1, 14), fontsize = 12, color = "red")

plt.scatter(lat_northern_hemi, windspeed_northern_hemi)
plt.plot(lat_northern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.003862590038983182

# %%
# Southern Hemisphere
windspeed_southern_hemi = southern_hemi_df["Wind Speed"]
lat_southern_hemi = southern_hemi_df["Lat"]

temp_slope, temp_int, temp_r, temp_p, temp_std_err = linregress(lat_southern_hemi, windspeed_southern_hemi)
temp_fit = temp_slope * lat_southern_hemi + temp_int
temp_line = "y =" + str(round(temp_slope, 2)) + "x + " + str(round(temp_int, 2))

correlation_4_southern_hemi = pearsonr(lat_southern_hemi, windspeed_southern_hemi)

plt.figure(figsize= (4,3))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(temp_line, (-30, 13), fontsize = 12, color = "red")

plt.scatter(lat_southern_hemi, windspeed_southern_hemi)
plt.plot(lat_southern_hemi, temp_fit, color ="red")
print(f"The r-value is: {temp_r**2}")
plt.show()
# Out:
# The r-value is: 0.04788321686542206

# %% [markdown]
# **Discussion about the linear relationship:** There is almost zero correlation between latitude and wind spped in the northern hemisphere. There is a small negative correlaton between tlatitude and wind speed in the southern hemisphere.
